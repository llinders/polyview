# %% [markdown]
# # Graphs

# %%
from IPython.core.display import Image

from src.polyview.workflows.perspective_analysis import (
    graph as perspective_analysis_graph,
)

display(Image(perspective_analysis_graph.get_graph().draw_mermaid_png()))

# %%
from src.polyview.workflows.research_workflow import graph as research_workflow_graph

display(Image(research_workflow_graph.get_graph().draw_mermaid_png()))
